# %%
#Homework Assignment 2
#Name: 김지현
#Time Spent: 10:29


# 6.00 Problem Set 3
# 
# Hangman
#


# -----------------------------------
# Helper code
# (you don't need to understand this helper code)
import random
import string

WORDLIST_FILENAME = "words.txt"

def load_words():
    """v
    
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print ("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split(" ")

    print (len(wordlist), "words loaded.")
    return wordlist

def choose_word(wordlist):
    """
    wordlist (list): list of words (strings)

    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code
# -----------------------------------

# actually load the dictionary of words and point to it with 
# the wordlist variable so that it can be accessed from anywhere
# in the program
wordlist = load_words()


# your code begins here!

def DisplayGame(correctLetters, secretWord):
    blanks = '_' * len(secretWord)
    for i in range(len(secretWord)):
        if secretWord[i] in correctLetters:
            blanks = blanks[:i] + secretWord[i] + blanks[i+1:]

    check=''
    for letter in blanks:
        check=check+" "+letter
    if guess_spelling in secretWord:    
        print("Good guess:",check)
        print()
        print("-------------------------------------------")
    elif guess_spelling not in secretWord:    
        print("Oops! That letter is not in my word:",check)
        print()
        print("-------------------------------------------")


print("Welcome to the game, Hangman!")    
correctLetters = ''
secretWord = choose_word(wordlist)
print("I am thinking of a word that is",len(secretWord),"letters long.")
gameFinish = False
alp='abcdefghijklmnopqrstuvwxyz'
life=len(secretWord)+3
print("-------------------------------------------")
print("You have",life,"guesses left.")


while True:
    if life>0:
        print('Available letters:', alp)
        guess_spelling = str(input('Please guess a letter: ')).lower()

        i=0

        while True:
            if alp[i]==guess_spelling:
                alp=alp[0:i]+alp[i+1:len(alp[:])]
                break
            else:
                i+=1
       
        if guess_spelling  not in secretWord:
            life-=1
            DisplayGame(correctLetters, secretWord)
            print("You have",life,"guesses left.")
        
        if guess_spelling in secretWord:
            correctLetters = correctLetters + guess_spelling
            foundAllLetters = True
            for i in range(len(secretWord)):
                if secretWord[i] not in correctLetters:
                    foundAllLetters = False
                    break
            if foundAllLetters:
                print("good guess:",secretWord)
                print("-------------------------------------------")
                print("Congratulations, you won!")
                gameFinish = True
        
            else:
                DisplayGame(correctLetters, secretWord)
            
                if guess_spelling  not in secretWord:
                    life-=1
                    print("You have",life,"guesses left.")
                elif guess_spelling  in secretWord:
                    print("You have",life,"guesses left.")
                
        if gameFinish:
            break
    else:
        print("Game over!")
        print("Answer is",secretWord)
        break
# Out:
# Loading word list from file...
# 55900 words loaded.
# Welcome to the game, Hangman!
# I am thinking of a word that is 9 letters long.
# -------------------------------------------
# You have 12 guesses left.
# Available letters: abcdefghijklmnopqrstuvwxyz
# Please guess a letter: a
# Good guess:  _ a _ _ _ a _ _ _
#
# -------------------------------------------
# You have 12 guesses left.
# Available letters: bcdefghijklmnopqrstuvwxyz
# Please guess a letter: b
# Oops! That letter is not in my word:  _ a _ _ _ a _ _ _
#
# -------------------------------------------
# You have 11 guesses left.
# Available letters: cdefghijklmnopqrstuvwxyz
# Please guess a letter: c
# Good guess:  _ a c _ _ a _ _ _
#
# -------------------------------------------
# You have 11 guesses left.
# Available letters: defghijklmnopqrstuvwxyz
# Please guess a letter: d
# Good guess:  _ a c _ _ a _ _ d
#
# -------------------------------------------
# You have 11 guesses left.
# ...
